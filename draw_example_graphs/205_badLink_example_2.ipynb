# %%
import networkx as nx

import matplotlib.pyplot as plt
# %matplotlib inline
import pydot
from networkx.drawing.nx_pydot import graphviz_layout

# %%
def draw_edge(tree, edge, color, curvature, edge_label = '', edge_width = 2, linestyle = '--'):
    nx.draw_networkx_edges(
        tree, 
        pos = pos, 
        edgelist = [edge],  
        edge_color = color,
        connectionstyle=f'arc3,rad={curvature}', 
        arrowstyle = '-',
        style = linestyle,
        width = edge_width,
        node_size = 100
    )
    nx.draw_networkx_edge_labels(tree, pos = pos, edge_labels = {edge: edge_label}, font_size = 12, font_color = 'C0', bbox = dict(alpha=0))

# %%
fig, ax = plt.subplots(1,1,tight_layout = True)
fig.set_size_inches(8, 4)

plt.sca(ax)
plt.axis('off')
tree = nx.Graph([
    (1,2), (1,3), (2,4), (2,5), (4,8), (5,9), (3,6), (3,7)
])

directed_tree = nx.bfs_tree(tree, 1)
pos = graphviz_layout(directed_tree, prog="dot")
nx.draw_networkx(
    directed_tree,
    pos = pos,
    edge_color = 'black',
    node_color = 'black',
    node_size = 100,
    arrowstyle = '-',
    width = 1.5,
    with_labels = False
)

draw_edge(directed_tree, (2,6), 'C0', 0.2)
draw_edge(directed_tree, (5,6), 'C0', 0.2)
draw_edge(directed_tree, (6,7), 'C1', 0.2)
draw_edge(directed_tree, (7,8), 'C0', -0.3)
draw_edge(directed_tree, (7,9), 'C0', -0.2)
draw_edge(directed_tree, (7,4), 'C0', -0.34)

draw_edge(directed_tree, (1,3), 'red', 0, edge_width = 4, linestyle = '-')




plt.savefig('../presentation_images/badLink_example_2.png', dpi = 200)
plt.show()
